# %%
import pandas as pd
import numpy as np

df_food = pd.read_csv('../Data_Base/FAO.csv', sep=',', encoding='ISO-8859-1')

# %%
df_food.tail()
# Out:
#       Area Abbreviation  Area Code      Area  Item Code  \
# 21472               ZWE        181  Zimbabwe       2948
# 21473               ZWE        181  Zimbabwe       2960
# 21474               ZWE        181  Zimbabwe       2960
# 21475               ZWE        181  Zimbabwe       2961
# 21476               ZWE        181  Zimbabwe       2928
#
#                           Item  Element Code Element         Unit  latitude  \
# 21472  Milk - Excluding Butter          5142    Food  1000 tonnes    -19.02
# 21473            Fish, Seafood          5521    Feed  1000 tonnes    -19.02
# 21474            Fish, Seafood          5142    Food  1000 tonnes    -19.02
# 21475  Aquatic Products, Other          5142    Food  1000 tonnes    -19.02
# 21476            Miscellaneous          5142    Food  1000 tonnes    -19.02
#
#        longitude  ...  Y2004  Y2005  Y2006  Y2007  Y2008  Y2009  Y2010  Y2011  \
# 21472      29.15  ...  373.0  357.0  359.0  356.0  341.0  385.0  418.0  457.0
# ...

# %%
df_canada = df_food[df_food['Area'] == 'Canada']

# %%
df_canada = df_canada.drop(df_canada.iloc[:, 10:60],axis=1)

# %%
df_canada
# Out:
#      Area Abbreviation  Area Code    Area  Item Code  \
# 3386               CAN         33  Canada       2511
# 3387               CAN         33  Canada       2511
# 3388               CAN         33  Canada       2805
# 3389               CAN         33  Canada       2513
# 3390               CAN         33  Canada       2513
# ...                ...        ...     ...        ...
# 3521               CAN         33  Canada       2948
# 3522               CAN         33  Canada       2960
# 3523               CAN         33  Canada       2960
# 3524               CAN         33  Canada       2961
# 3525               CAN         33  Canada       2928
#
#                           Item  Element Code Element         Unit  latitude  \
# 3386        Wheat and products          5521    Feed  1000 tonnes     56.13
# 3387        Wheat and products          5142    Food  1000 tonnes     56.13
# 3388  Rice (Milled Equivalent)          5142    Food  1000 tonnes     56.13
# ...

# %%
df_canada['aux'] = np.NaN

# %%
df_canada.head()
# Out:
#      Area Abbreviation  Area Code    Area  Item Code  \
# 3386               CAN         33  Canada       2511
# 3387               CAN         33  Canada       2511
# 3388               CAN         33  Canada       2805
# 3389               CAN         33  Canada       2513
# 3390               CAN         33  Canada       2513
#
#                           Item  Element Code Element         Unit  latitude  \
# 3386        Wheat and products          5521    Feed  1000 tonnes     56.13
# 3387        Wheat and products          5142    Food  1000 tonnes     56.13
# 3388  Rice (Milled Equivalent)          5142    Food  1000 tonnes     56.13
# 3389       Barley and products          5521    Feed  1000 tonnes     56.13
# 3390       Barley and products          5142    Food  1000 tonnes     56.13
#
#       longitude   Y2011  Y2012  Y2013  aux
# 3386    -106.35  3338.0   3410   3731  NaN
# 3387    -106.35  2724.0   2992   2989  NaN
# 3388    -106.35   317.0    316    445  NaN
# ...

# %%
df_canada.drop('aux', axis=1, inplace=True)

# %%
df_canada.head()
# Out:
#      Area Abbreviation  Area Code    Area  Item Code  \
# 3386               CAN         33  Canada       2511
# 3387               CAN         33  Canada       2511
# 3388               CAN         33  Canada       2805
# 3389               CAN         33  Canada       2513
# 3390               CAN         33  Canada       2513
#
#                           Item  Element Code Element         Unit  latitude  \
# 3386        Wheat and products          5521    Feed  1000 tonnes     56.13
# 3387        Wheat and products          5142    Food  1000 tonnes     56.13
# 3388  Rice (Milled Equivalent)          5142    Food  1000 tonnes     56.13
# 3389       Barley and products          5521    Feed  1000 tonnes     56.13
# 3390       Barley and products          5142    Food  1000 tonnes     56.13
#
#       longitude   Y2011  Y2012  Y2013
# 3386    -106.35  3338.0   3410   3731
# 3387    -106.35  2724.0   2992   2989
# 3388    -106.35   317.0    316    445
# ...

# %%
df_canada.groupby('Element').sum()
# Out:
#          Area Code  Item Code  Element Code  latitude  longitude    Y2011  \
# Element
# Feed          1122      92153        187714   1908.42    -3615.9  38178.0
# Food          3498     285195        545052   5949.78   -11273.1  67747.0
#
#          Y2012  Y2013
# Element
# Feed     41688  52274
# Food     67319  67893

# %%
df_canada.groupby('Element').sum().iloc[:,5:8]
# Out:
#            Y2011  Y2012  Y2013
# Element
# Feed     38178.0  41688  52274
# Food     67747.0  67319  67893

# %%
df_aux = df_canada.groupby('Element').sum().iloc[:,5:8]
df_aux
# Out:
#            Y2011  Y2012  Y2013
# Element
# Feed     38178.0  41688  52274
# Food     67747.0  67319  67893

# %%
df_aux.sum(axis=1)
# Out:
# Element
# Feed    132140.0
# Food    202959.0
# dtype: float64

# %%
df_food[df_food['Area Abbreviation']=='ZWE'].count()
# Out:
# Area Abbreviation    121
# Area Code            121
# Area                 121
# Item Code            121
# Item                 121
#                     ...
# Y2009                121
# Y2010                121
# Y2011                121
# Y2012                121
# Y2013                121
# Length: 63, dtype: int64

# %%
df_food[df_food['Area Abbreviation']=='AFG'].iloc[:5, 10:15]
# Out:
#     Y1961   Y1962   Y1963   Y1964   Y1965
# 0  1928.0  1904.0  1666.0  1950.0  2001.0
# 1   183.0   183.0   182.0   220.0   220.0
# 2    76.0    76.0    76.0    76.0    76.0
# 3   237.0   237.0   237.0   238.0   238.0
# 4   210.0   210.0   214.0   216.0   216.0

# %%
area_abbreviation = df_food['Area Abbreviation'].value_counts()
# Out:
# <bound method Series.sort_index of CHN    541
# THA    261
# AZE    240
# ESP    150
# ITA    148
#       ...
# GNB     91
# TKM     90
# TLS     86
# AFG     83
# LSO     75
# Name: Area Abbreviation, Length: 169, dtype: int64>

# %%
df_food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21477 entries, 0 to 21476
# Data columns (total 63 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Area Abbreviation  21477 non-null  object
#  1   Area Code          21477 non-null  int64
#  2   Area               21477 non-null  object
#  3   Item Code          21477 non-null  int64
#  4   Item               21477 non-null  object
#  5   Element Code       21477 non-null  int64
#  6   Element            21477 non-null  object
#  7   Unit               21477 non-null  object
#  8   latitude           21477 non-null  float64
#  9   longitude          21477 non-null  float64
#  10  Y1961              17938 non-null  float64
#  11  Y1962              17938 non-null  float64
#  12  Y1963              17938 non-null  float64
#  13  Y1964              17938 non-null  float64
#  14  Y1965              17938 non-null  float64
#  15  Y1966              17938 non-null  float64
# ...
